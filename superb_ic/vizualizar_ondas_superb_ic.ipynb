# %% [markdown]
# # Importando bibliotecas

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio
from scipy.io import wavfile

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# # Rodando Classificador na Original

# %%
import pandas as pd
train = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_original.pkl')

# %%
train.head()
# Out:
#                                                     file  \
# 9276   /root/.cache/huggingface/datasets/downloads/ex...
# 14057  /root/.cache/huggingface/datasets/downloads/ex...
# 2795   /root/.cache/huggingface/datasets/downloads/ex...
# 13856  /root/.cache/huggingface/datasets/downloads/ex...
# 21285  /root/.cache/huggingface/datasets/downloads/ex...
#
#                                                    audio  label
# 9276   {'path': '/root/.cache/huggingface/datasets/do...      4
# 14057  {'path': '/root/.cache/huggingface/datasets/do...      1
# 2795   {'path': '/root/.cache/huggingface/datasets/do...      3
# 13856  {'path': '/root/.cache/huggingface/datasets/do...      1
# 21285  {'path': '/root/.cache/huggingface/datasets/do...      5

# %%
import pickle
label2id = pickle.load(open("/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_label2id.pkl", "rb"))
id2label = pickle.load(open("/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_id2label.pkl", "rb"))

# %%
test_file = train.file.iloc[4]

# %%
from IPython.display import Audio, display

example = train[train.file == test_file].copy()
audio = example["audio"].iloc[0]

print(f'Label: {id2label[str(example["label"].iloc[0])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (36864,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])

# %% [markdown]
# # Speed Pertubation

# %%
speed = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_speed_pertub.pkl')

# %%
example = speed[speed.file == test_file].copy()
audio = example["audio"].iloc[2]

print(f'Label: {id2label[str(example["label"].iloc[2])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (37233,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])

# %% [markdown]
# # Pitch Shift

# %%
pitch = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_pitch_shift.pkl')

# %%
example = pitch[pitch.file == test_file].copy()
audio = example["audio"].iloc[2]

print(f'Label: {id2label[str(example["label"].iloc[2])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (36864,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])

# %% [markdown]
# # Peaking Filter

# %%
peak = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_peak_filter.pkl')

# %%
example = peak[peak.file == test_file].copy()
audio = example["audio"].iloc[2]

print(f'Label: {id2label[str(example["label"].iloc[2])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (36864,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])

# %% [markdown]
# # Add Noise

# %%
noise = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_add_noise.pkl')

# %%
example = noise[noise.file == test_file].copy()
audio = example["audio"].iloc[2]

print(f'Label: {id2label[str(example["label"].iloc[2])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (36864,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])

# %% [markdown]
# # LPCAug

# %%
lpc = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/audio_ml/datasets/superb_ic_lpcaug.pkl')

# %%
example = lpc[lpc.file == test_file].copy()
audio = example["audio"].iloc[2]

print(f'Label: {id2label[str(example["label"].iloc[2])]}')
print(f'Shape: {audio["array"].shape}, sampling rate: {audio["sampling_rate"]}')
display(Audio(audio["array"], rate=audio["sampling_rate"]))
print()
# Out:
# Label: increase
# Shape: (36864,), sampling rate: 16000
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio["array"],audio["sampling_rate"])
